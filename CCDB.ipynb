# %%
import cppyy
# Out:
# /Users/tom/alice/sw/osx_x86-64/ROOT/v6-24-06-patches-alice1-local1/lib/cppyy_backend/loader.py:113: UserWarning: No precompiled header available (/Users/tom/alice/sw/osx_x86-64/ROOT/v6-24-06-patches-alice1-local1/lib/cppyy_backend/etc not writable); this may impact performance.
#   warnings.warn('No precompiled header available (%s); this may impact performance.' % msg)

# %%
import ROOT

# %jsroot on

ccdb = ROOT.o2.ccdb.BasicCCDBManager.instance()

ccdb.setURL("http://ccdb-test.cern.ch:8080") # test CCDB/QCDB
# ccdb.setURL("http://ali-qcdb.cern.ch:8083") # production database
# Out:
# Welcome to JupyROOT 6.24/06

# %%
ph = ccdb.get[ROOT.TH1F]("qc/TRD/MO/PulseHeight/mPulseHeight")
cnv = ROOT.TCanvas("cnv_ph")
ph.Draw()
cnv.Draw()
# Out:
# <div id="root_plot_1653612428410"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1653612428410(Core) {
# ...

# %%
ph2d = ccdb.get[ROOT.TProfile2D]("qc/TRD/MO/PulseHeight_upasana/mPulseHeightperchamber")

# %%
cnv = ROOT.TCanvas("cnv_ph")
ph2d.Draw("colz")
cnv.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: cnv_ph
# <div id="root_plot_1653612438714"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1653612438714(Core) {
# ...

# %%
cnv = ROOT.TCanvas("cnv_ph_profile")
phprof = ph2d.ProfileX().DrawCopy()
cnv.Draw()
# Out:
# <div id="root_plot_1653612444675"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1653612444675(Core) {
# ...

# %%
cnv = ROOT.TCanvas("cnv_ph_projection")
phproj = ph2d.ProjectionX().DrawCopy()
cnv.Draw()
# Out:
# <div id="root_plot_1653612450730"
#      style="width: 696px; height: 472px">
# </div>
# <script>
#
# function display_root_plot_1653612450730(Core) {
# ...
